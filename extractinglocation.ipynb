# %%
import spacy
from data.function import Categories

nlp = spacy.load('en_core_web_sm')

def extract_location(text):
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_ == "GPE":
            return ent.text
    return None


def noun(text):
    cleantext = text.replace('"','').replace("'","")
    doc = nlp(cleantext)
    group = []
    for i in doc.noun_chunks:
        group.append(i.text)
    return group

def match_stock(noun):
    stock = Categories().get_all_stock()
    matching = []
    for i in noun:
        if i in stock:
            matching.append(i)
    return list(set(matching))
            
def location(noun):
    stock = Categories().get_all_stock()
    possible_location = []
    for i in noun:
        if i in stock:
            continue
        doc = nlp(i)
        for ent in doc.ents:
            if ent.label_ == "GPE" or ent.label_ == "PERSON" or ent.label_ == "ORG":
                possible_location.append(i)
    possible_location = list(set(possible_location))
    return possible_location

# %%
text = "Entering the earnings announcement period for the 4th quarter of 2022 and the 2022 period of companies listed on the Stock Exchange of Thailand (Co. Ltd.), most recently, companies in the Jay Mart group consisting of JMART, JMT, SINGER, J and SGC have reported results. The work has been completed as follows:by Jay Mart Public Company Limited or JMART has a net profit in the year 2012 at 1,794.96 million baht, a decrease of 27.26% from the same period last year with a profit of 2,467.60 million baht as a result of the company's cost of sales and expenses. Increased spending on sales and servicesMaybank Securities (Thailand) stated in the analysis that the trend in 2023 will grow prominently, combined with synergy in the group and cooperation with other companies will be a profit driver. Recommend a target price of 75 baht.As for JMT Network Services Public Company Limited or JMT, it reported a net profit in 2022 of 1,746 million baht, an increase of 24.65% from the same period last year with a profit of 1,400.37 million baht due to revenue. The total amount was 4,410 million baht, an increase of 22% from the same period last year. able to manage and outstanding storage With debt collection (Cash Collection), including JK AMC's group, doing well at 6,345 million baht, growing 38%.by Dao Securities (Thailand) stated in the analysis that We maintain our 2023 net profit forecast at 2.2 billion baht, an increase of 26% from the same period last year. from buying bad debt remained stable at 5 billion baht, fee income increased 52% from the same period last year. from higher contract debt after the end of debtor assistance measures and JK AMC's contract increased and realized profit sharing from JK AMC increased to 434 million baht. Recommend BUY with a target price of 64 baht.For Singer Thailand Public Company Limited or SINGER, net profit in 2022 was 935.28 million baht, an increase of 33.50% from the same period last year with a profit of 700.59 million baht as a result of increased interest income. mainlyDao Securities (Thailand) stated in the analysis that We maintain our 2023 net profit forecast at 1.1 billion baht, an increase of 22% from the same period last year. from loan growth of 29% from the same period last year. Especially C4C loans that grew well 40% from the same period last year. Due to the expansion of the customer base, the demand for credit increases during the economic expansion. And a positive result from synergy with BRR, including a decrease in NPL to 4.3% in proportion to C4C loans with low NPL, recommending a target price of 36 baht.While JAS Asset Public Company Limited or J reported a net profit in 2022 of 202.34 million baht, an increase of 25.33% from the same period last year with a profit of 161.44 million baht as a result of the company. The launch of a new project, The JAS Green Village, Khubon, at the end of 2021, allowing the company to recognize revenue from rental space for a full year. and increased revenue from real estate sales and improvement of shopping centers and rental spaces for better occupancy rates. which is according to the economic situation and the situation of COVID-19 relaxedBy Mr. Suphot Sirikulpat Chief Executive Officer J stated that in 2023, he was confident that J would run faster and more agile. with a clear business structure By the real estate business for investment in the development of community shopping centers at the end of the year 2022, there are 5 projects, consisting of The Jas Wang Hin, The Jas Ramintra, Jas Urban Srinakarin, Jas Village Amata, Chonburi and Jas Green Village Khubon, and is expected to open more this year. Two more projects, Jas Green Village Bang Bua Thong and Jas Green Village Ramkhamhaeng, support the company's rental space. increased to almost 100,000 square meters, generating more cash inflowsfor an overview of the expansion of the health business and care for the elderly The company launched a home for the elderly under the brand Senera Senior Wellness at the end of last year. Confident that it will strengthen the company's revenue base.SG Capital Public Company Limited or SGC had a net profit in 2012 of 667.24 million baht, an increase of 12.51% from the same period last year with a profit of 593.03 million baht as a result of increased total revenue. It came from increased interest income, including hire-purchase loans for electrical appliances. money making car loan welfare loan and other income which consists of commission income Mainly fee income"
n = noun(text)
loc = location(n)
stock = match_stock(n)
print(stock)

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="my_application")

def extract_location(text):
    location = geolocator.geocode(text)
    if location:
        return (text,location.latitude,location.longitude)
    return None

# text = "เลย"
for text in loc:
    print(extract_location(text))

# %%
from data.function import Location,News,Stock

cbg = Stock('CBG')
cbg.get_location()


# location = Location()
# news = News()

# location.fetch_location()

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("PTT Public Company Limited or PTT disclosed the operating results for the 4th quarter of 2022, the company had a net profit of 17,872 million baht or more than 100.0 percent from the 3rd quarter of 2022 at 8,884 million baht.")
for noun in doc.noun_chunks:
    print(noun)
# Out:
# PTT Public Company Limited
# PTT
# the operating results
# the 4th quarter
# the company
# a net profit
# 17,872 million baht
# more than 100.0 percent
# the 3rd quarter
# 8,884 million baht

# %%
for noun in doc.noun_chunks:
    print(noun)
# Out:
# PTT Public Company Limited
# PTT
# the operating results
# the 4th quarter
# the company
# a net profit
# 17,872 million baht
# more than 100.0 percent
# the 3rd quarter
# 8,884 million baht

# %%
from data.function import Location,News
location = Location('set')
print(location.location_upgrade('I went to Bangkok after that I went to Phuket with my friend that came from Paris'))
# Out:
# ['Phuket', 'Bangkok', 'Paris']

# %%
from data.function import Location
location = Location('set')
location.extract_lat_lon('bangkok')
# Out:
# {'lat': '13.7524938', 'lon': '100.4935089'}

# %%
tran = News('set').combine_translate(61)
print(tran)
# Out:
# Norway accuses PTT-OR of supporting Myanmar's atrocities, orders pension funds to ban both investments Reporters report on the coup in Myanmar on the morning of February 1, 2021, with the Burma Army declaring a state of emergency a few hours later. And finally, there is a transfer of power to Senior General Min Aung Lai. Supreme Commander and head of the coup at that time western group Led by the United States and its allies, they condemned and opposed the coup. until the situation rapidly deteriorated This has resulted in demands and legislation forcing many foreign companies to stop investing. as well as all operations in Myanmar in order not to support the coup that may be considered a violation of human rights and the privacy rights of the Myanmar people seriously. It is reported that the PTT group has received letters from governments of many countries condemning the violence. by calling for the cessation of all operations in Myanmar Since many of PTT's affiliates have invested a lot and in a variety of business types The PTT Group has made several clarification letters certified by the Ministry of Foreign Affairs of Thailand. He reaffirmed that the group had no involvement in supporting the coup and violating human rights. But all investments are related to energy security for Thailand only. However, the reporter reported that on May 10, 2022, the Council on Ethics of Norwegian Goverment Pension Fund Global GPFG suggested that the fund Stop investing in shares of PTT Public Company Limited or PTT and PTT Oil and Retail Public Company Limited or OR, which was the latest on December 15, the GPFG fund by the Bank of Norway. Norge Bank has taken steps to exclude shares of both companies from its investment portfolio. The Ethics Council stated the reason for the said recommendation that Due to various business activities of the PTT Group bring unacceptable risks. for engaging with the Myanmar government in serious violations of privacy rights As well as supporting the events of wars and various disputes that arise. PTT Exploration and Production Public Company Limited (PTTEP), a subsidiary of PTT, has entered into a partnership with Myanmar Oil and Gas (MOGE) in an offshore natural gas exploration and production project in Myanmar. of 3 sources while OR, which is another subsidiary It has entered into a joint venture with the Myanmar Economic Corporation (MEC) owned by the Burma Army. For the construction and operation of oil storage services or Oil Terminal and liquefied natural gas filling business or LNG Filling Facility. Recommendations from the Ethics Council In a nutshell, PTT and OR's business activities contribute to the revenue stream for the Burma Army's armed forces. that will be used in military activities for violations of privacy rights The partnership with MOGE and MEC reflects the unacceptable risks GPFG faces in supporting future brutality against the people of Myanmar.  The correspondent reports additionally from investigating the shareholding structure of one of the three projects of PTTEP referred to as The Yadana Project found that Unocal Myanmar Offshore Company Limited, a subsidiary of Chevron, an American company, is the number one largest shareholder with a stake of 41.1016%, followed by PTTEPI in the PTT Group with a stake of 37.0842%, and the last is MOGR, holding a stake of 21.8142%. Therefore, it was noted that Why are American companies like Chevron immune to condemnation and penalties for investing? because it is currently the largest shareholder and has received additional shares from Total, a French company who withdrew their investment earlier as well Meanwhile, the US government It is the mainstay of opposition to and condemning the Burma Army government of Myint Aung Laing. PTTEP, or PTTEP, had previously revealed to the news team. News about business stocks Previously, on issues that are related that Investing in Myanmar is considered to create energy security. decision to undertake this p ...

# %%
location = Location('set')
print(location.location_upgrade(tran))
# Out:
# ['Norway', 'the United States', 'Yadana Project', 'US', 'Myanmar', 'Investing', 'Thailand']

# %%
from data.function import Location,News
new = News('set')
new.fetch_news('THCOM')

# %%
lo = Location('set')
lo.fetch_location('THCOM')

# %%
from data.function import Location
lo = Location('set')
lo.get_stock_location('PTT')
# Out:
# [(3, 'Thailand', 14.8971921, 100.83273),
#  (5, 'Malaysia', 4.5693754, 102.2656823),
#  (5, 'US', 39.7837304, -100.445882),
#  (8, 'US', 39.7837304, -100.445882),
#  (10, 'Phanthong', 48.5788175, 7.7549181),
#  (10, 'Thailand', 14.8971921, 100.83273),
#  (11, 'China', 35.000074, 104.999927),
#  (12, 'US', 39.7837304, -100.445882),
#  (12, 'New York', 40.7127281, -74.0060152),
#  (12, 'Turkey', 38.9597594, 34.9249653),
#  (12, 'China', 35.000074, 104.999927),
#  (13, 'US', 39.7837304, -100.445882),
#  (14, 'Bangkok', 13.7524938, 100.4935089),
#  (14, 'Thailand', 14.8971921, 100.83273),
#  (14, 'River City Bangkok', 13.7305367, 100.5133018478582),
#  (15, 'Thailand', 14.8971921, 100.83273),
#  (17, 'Xayaburi', 19.2536139, 101.61809849627492),
#  (17, 'IU', 29.3093002, 120.0703805),
#  (17, 'However', 51.0542952, -1.3381888),
#  (22, 'China', 35.000074, 104.999927),
#  (22, 'US', 39.7837304, -100.445882),
#  (24, 'US', 39.7837304, -100.445882),
#  (25, 'US', 39.7837304, -100.445882),
#  (26, 'Thailand', 14.8971921, 100.83273),
#  (26, 'Chanchai', 23.158228, 88.0260605),
#  (26, 'Taiwan', 23.9739374, 120.9820179),
#  (26, 'Singapore', 1.357107, 103.8194992),
#  (27, 'Philippines', 12.7503486, 122.7312101),
#  (27, 'Taiwan', 23.9739374, 120.9820179),
#  (27, 'Kuala Lumpur', 3.1516964, 101.6942371),
#  (27, 'Vietnam', 15.9266657, 107.9650855),
#  (27, 'Malaysia', 4.5693754, 102.2656823),
#  (27, 'Indonesia', -2.4833826, 117.8902853),
#  (27, 'Chiang Mai', 18.7882778, 98.9858802),
#  (27, 'Japan', 36.5748441, 139.2394179),
#  (27, 'China', 35.000074, 104.999927),
#  (27, 'Hong Kong', 22.2793278, 114.1628131),
#  (27, 'Singapore', 1.357107, 103.8194992),
#  (27, 'Lanna', 57.2235168, 13.7776472),
#  (28, 'US', 39.7837304, -100.445882),
#  (28, 'Thailand', 14.8971921, 100.83273),
#  (28, 'JUBILE', 46.2289228, 3.7265469),
#  (28, 'China', 35.000074, 104.999927),
#  (28, 'SYNEX', 48.270897, 14.2683233),
#  (28, 'CENTEL', -16.072583, -47.9816269),
#  (29, 'US', 39.7837304, -100.445882),
#  (30, 'China', 35.000074, 104.999927),
#  (32, 'US', 39.7837304, -100.445882),
#  (33, 'China', 35.000074, 104.999927),
#  (34, 'China', 35.000074, 104.999927),
#  (35, 'China', 35.000074, 104.999927),
#  (35, 'Thailand', 14.8971921, 100.83273),
#  (35, 'US', 39.7837304, -100.445882),
#  (36, 'China', 35.000074, 104.999927),
#  (36, 'Thailand', 14.8971921, 100.83273),
#  (36, 'US', 39.7837304, -100.445882),
#  (38, 'China', 35.000074, 104.999927),
#  (39, 'Bangkok', 13.7524938, 100.4935089),
#  (40, 'China', 35.000074, 104.999927),
#  (40, 'Thailand', 14.8971921, 100.83273),
#  (40, 'Watan', 13.501, 15.8365667),
#  (42, 'Bangkok', 13.7524938, 100.4935089),
#  (42, 'Rayong province', 12.7943716, 101.3705344),
#  (43, 'US', 39.7837304, -100.445882),
#  (44, 'Erawan', 17.3693597, 101.8920754),
#  (45, 'Brazil', -10.3333333, -53.2),
#  (45, 'China', 35.000074, 104.999927),
#  (45, 'India', 22.3511148, 78.6677428),
#  (45, 'US', 39.7837304, -100.445882),
#  (46, 'New York', 40.7127281, -74.0060152),
#  (46, 'the United States', 29.6330078, -97.98859404468138),
#  (46, 'Russia', 64.6863136, 97.7453061),
#  (47, 'US', 39.7837304, -100.445882),
#  (48, 'Thailand', 14.8971921, 100.83273),
#  (48, 'US', 39.7837304, -100.445882),
#  (50, 'Thailand', 14.8971921, 100.83273),
#  (52, 'YoY', 46.9000015, -71.5),
#  (52, 'Thailand', 14.8971921, 100.83273),
#  (53, 'the United States', 29.6330078, -97.98859404468138),
#  (53, 'US', 39.7837304, -100.445882),
#  (53, 'Thailand', 14.8971921, 100.83273),
#  (53, 'Myanmar', 17.1750495, 95.9999652),
#  (53, 'The United States', 35.4156039, -78.23584441420257),
#  (53, 'Yadana', 36.9863599, 35.3252861),
#  (53, 'France', 46.603354, 1.8883335),
#  (55, 'US', 39.7837304, -100.445882),
#  (56, 'Myanmar', 17.1750495, 95.9999652),
#  (56, 'Norway', 61.1529386, 8.7876653),
#  (57, 'China', 35.000074, 104.999927),
#  (57, 'CENTEL', -16.072583, -47.9816269),
#  (57, 'JAS', 45.7454596, 4.3112977),
#  (58, 'Argentina', -34.9964963, -64.9672817),
#  (58, 'US', 39.7837304, -100.445882),
#  (58, 'Myanmar', 17.1750495, 95.9999652),
#  (58, 'Norway', 61.1529386, 8.7876653),
#  (58, 'Lionel Messi', -36.5107464, -63.8607721),
#  (58, 'England', 52.5310214, -1.2649062),
#  (58, 'France', 46.603354, 1.8883335),
#  (59, 'China', 35.000074, 104.999927),
#  (59, 'Myanmar', 17.1750495, 95.9999652),
#  (61, 'the United States', 29.6330078, -97.98859404468138),
#  (61, 'US', 39.7837304, -100.445882),
#  (61, 'Thailand', 14.8971921, 100.83273),
#  (61, 'Myanmar', 17.1750495, 95.9999652),
#  (61, 'Norway', 61.1529386, 8.7876653),
#  (61, 'Investing', 54.170683, 19.4021641),
#  (62, 'China', 35.000074, 104.999927),
#  (62, 'the United States', 29.6330078, -97.98859404468138),
#  (63, 'China', 35.000074, 104.999927),
#  (63, 'US', 39.7837304, -100.445882),
#  (64, 'Thailand', 14.8971921, 100.83273),
#  (65, 'Thailand', 14.8971921, 100.83273),
#  (65, 'EV', 38.3881754, 27.05477765852585),
#  (72, 'China', 35.000074, 104.999927),
#  (72, 'US', 39.7837304, -100.445882),
#  (74, 'US', 39.7837304, -100.445882),
#  (75, 'US', 39.7837304, -100.445882),
#  (76, 'Thailand', 14.8971921, 100.83273),
#  (78, 'Research', -37.7066557, 145.189067),
#  (78, 'the United States', 29.6330078, -97.98859404468138),
#  (78, 'US', 39.7837304, -100.445882),
#  (79, 'U.S.', 48.6840558, 9.009657397144329),
#  (79, 'US', 39.7837304, -100.445882),
#  (80, 'Uncle', 35.6561848, 139.5266915),
#  (82, 'US', 39.7837304, -100.445882),
#  (83, 'China', 35.000074, 104.999927),
#  (84, 'Thailand', 14.8971921, 100.83273),
#  (84, 'US', 39.7837304, -100.445882),
#  (85, 'China', 35.000074, 104.999927),
#  (85, 'Thailand', 14.8971921, 100.83273),
#  (86, 'Vietnam', 15.9266657, 107.9650855),
#  (86, 'US', 39.7837304, -100.445882),
#  (89, 'China', 35.000074, 104.999927),
#  (89, 'Hong Kong', 22.2793278, 114.1628131),
#  (90, 'US', 39.7837304, -100.445882),
#  (91, 'China', 35.000074, 104.999927),
#  (91, 'Thailand', 14.8971921, 100.83273),
#  (92, 'US', 39.7837304, -100.445882),
#  (93, 'US', 39.7837304, -100.445882),
#  (94, 'US', 39.7837304, -100.445882),
#  (95, 'Saudi Arabia', 25.6242618, 42.3528328),
#  (97, 'Thailand', 14.8971921, 100.83273),
#  (100, 'Thailand', 14.8971921, 100.83273),
#  (101, 'US', 39.7837304, -100.445882),
#  (102, 'US', 39.7837304, -100.445882),
#  (104, 'India', 22.3511148, 78.6677428),
#  (104, 'Foxconn', 47.7427111, 18.08178848292425),
#  (104, 'Taiwan', 23.9739374, 120.9820179),
#  (105, 'US', 39.7837304, -100.445882),
#  (105, 'Russia', 64.6863136, 97.7453061),
#  (105, 'Ukraine', 49.4871968, 31.2718321),
#  (105, 'China', 35.000074, 104.999927),
#  (105, 'Poland', 52.215933, 19.134422),
#  (106, 'China', 35.000074, 104.999927),
#  (106, 'Thailand', 14.8971921, 100.83273),
#  (106, 'US', 39.7837304, -100.445882),
#  (109, 'Poland', 52.215933, 19.134422),
#  (110, 'China', 35.000074, 104.999927),
#  (111, 'China', 35.000074, 104.999927),
#  (111, 'Thailand', 14.8971921, 100.83273),
#  (112, 'US', 39.7837304, -100.445882),
#  (114, 'China', 35.000074, 104.999927),
#  (114, 'Thailand', 14.8971921, 100.83273),
#  (114, 'Which', 51.5243386, -0.14449479444444444),
#  (114, 'US', 39.7837304, -100.445882),
#  (114, "South Korea's", 36.9643355, 126.9984173),
#  (116, 'US', 39.7837304, -100.445882),
#  (117, 'Thailand', 14.8971921, 100.83273),
#  (117, 'US', 39.7837304, -100.445882),
#  (118, 'US', 39.7837304, -100.445882),
#  (119, 'US', 39.7837304, -100.445882),
#  (120, 'US', 39.7837304, -100.445882),
#  (120, 'China', 35.000074, 104.999927),
#  (121, 'US', 39.7837304, -100.445882),
#  (121, 'China', 35.000074, 104.999927),
#  (122, 'Salawan', 15.87128, 106.3389565),
#  (122, 'Nakhon Si Thammarat Province', 8.6772337, 99.7309635),
#  (123, 'Hong Kong', 22.2793278, 114.1628131),
#  (123, 'US', 39.7837304, -100.445882),
#  (123, 'the United States', 29.6330078, -97.98859404468138),
#  (123, 'China', 35.000074, 104.999927),
#  (124, 'Hong Kong', 22.2793278, 114.1628131),
#  (124, 'Watan', 13.501, 15.8365667),
#  (124, 'US', 39.7837304, -100.445882),
#  (126, 'Thailand', 14.8971921, 100.83273),
#  (126, 'US', 39.7837304, -100.445882),
#  (127, 'Zig', 18.562085, -9.818793),
#  (128, 'US', 39.7837304, -100.445882),
#  (130, 'Hong Kong', 22.2793278, 114.1628131),
#  (130, 'China', 35.000074, 104.999927),
#  (132, 'US', 39.7837304, -100.445882),
#  (134, 'US', 39.7837304, -100.445882),
#  (135, 'US', 39.7837304, -100.445882),
#  (136, 'US', 39.7837304, -100.445882),
#  (137, 'Watan', 13.501, 15.8365667),
#  (137, 'US', 39.7837304, -100.445882),
#  (140, 'N.N.B.A.', 51.5665206, 3.7001047),
#  (141, 'Big Soldier', 34.4626977, -84.28991414884334),
#  (142, 'Singapore', 1.357107, 103.8194992),
#  (142, 'Thailand', 14.8971921, 100.83273),
#  (142, 'Bangchak', 13.71106915, 100.54183276695969),
#  (142, 'Taiwan', 23.9739374, 120.9820179),
#  (142, 'France', 46.603354, 1.8883335),
#  (142, 'Canada', 61.0666922, -107.991707),
#  (143, 'USA', 39.7837304, -100.445882),
#  (145, 'US', 39.7837304, -100.445882),
#  (146, 'Thailand', 14.8971921, 100.83273),
#  (146, 'Dubai', 25.074282349999997, 55.18853865430702),
#  (146, '3P', 52.2198175, 20.958289773860223),
#  (147, 'Sideway', 52.9869492, -2.1835803),
#  (147, 'India', 22.3511148, 78.6677428),
#  (147, 'China', 35.000074, 104.999927),
#  (148, 'US', 39.7837304, -100.445882),
#  (149, 'US', 39.7837304, -100.445882),
#  (150, 'US', 39.7837304, -100.445882),
#  (151, 'US', 39.7837304, -100.445882),
#  (151, 'the United States', 29.6330078, -97.98859404468138),
#  (152, 'US', 39.7837304, -100.445882),
#  (153, 'Thailand', 14.8971921, 100.83273),
#  (153, 'Japan', 36.5748441, 139.2394179),
#  (154, 'US', 39.7837304, -100.445882),
#  (155, 'Thailand', 14.8971921, 100.83273),
#  (155, 'Rayong Province', 12.7943716, 101.3705344),
#  (156, 'Thailand', 14.8971921, 100.83273),
#  (156, 'US', 39.7837304, -100.445882),
#  (157, 'Thailand', 14.8971921, 100.83273),
#  (157, 'US', 39.7837304, -100.445882),
#  (158, 'Thailand', 14.8971921, 100.83273),
#  (159, 'Saudi Arabia', 25.6242618, 42.3528328),
#  (159, 'US', 39.7837304, -100.445882),
#  (159, 'Dubai', 25.074282349999997, 55.18853865430702),
#  (159, 'Russia', 64.6863136, 97.7453061),
#  (159, 'U.S.', 48.6840558, 9.009657397144329),
#  (162, 'US', 39.7837304, -100.445882),
#  (162, 'Russia', 64.6863136, 97.7453061),
#  (163, 'US', 39.7837304, -100.445882),
#  (164, 'Thailand', 14.8971921, 100.83273),
#  (164, 'US', 39.7837304, -100.445882),
#  (165, 'Thailand', 14.8971921, 100.83273),
#  (165, 'YoY', 46.9000015, -71.5),
#  (165, 'US', 39.7837304, -100.445882),
#  (166, 'US', 39.7837304, -100.445882),
#  (168, 'Q1/26', 30.0902127, 31.7023694),
#  (168, 'Thailand', 14.8971921, 100.83273),
#  (170, 'Plant', 46.2028017, 13.7822094),
#  (170, 'OR', 43.9792797, -120.737257),
#  (172, 'US', 39.7837304, -100.445882),
#  (173, 'US', 39.7837304, -100.445882),
#  (174, 'US', 39.7837304, -100.445882),
#  (178, 'Thailand', 14.8971921, 100.83273),
#  (178, 'ExpresSo', 49.1343842, -117.8277705),
#  (178, 'Mandala Capital', 4.6751286, -74.0610975),
#  (181, 'US', 39.7837304, -100.445882),
#  (183, 'Thailand', 14.8971921, 100.83273),
#  (183, 'US', 39.7837304, -100.445882),
#  (184, 'Thailand', 14.8971921, 100.83273),
#  (184, 'US', 39.7837304, -100.445882),
#  (186, 'Jackson Hole', 34.641109, -98.67619161204742),
#  (186, 'US', 39.7837304, -100.445882),
#  (187, 'US', 39.7837304, -100.445882),
#  (188, 'CENTEL', -16.072583, -47.9816269),
#  (188, 'KKP', 49.25261885, 8.438200600300252),
#  (190, 'South Korea', 36.638392, 127.6961188),
#  (190, 'China', 35.000074, 104.999927),
#  (190, 'Japan', 36.5748441, 139.2394179),
#  (190, 'Sichuan', 30.5000001, 102.4999999),
#  (190, 'US', 39.7837304, -100.445882),
#  (190, 'Philippines', 12.7503486, 122.7312101),
#  (190, 'Britain', 54.31536155, -1.91802349480124),
#  (190, 'Indonesia', -2.4833826, 117.8902853),
#  (190, 'India', 22.3511148, 78.6677428),
#  (191, 'US', 39.7837304, -100.445882),
#  (191, 'the United States', 29.6330078, -97.98859404468138),
#  (192, 'QT', 16.7897806, 106.9797431),
#  (192, 'Q1/23', 42.11355795, -71.86697947881134),
#  (194, 'the United States', 29.6330078, -97.98859404468138),
#  (194, 'Thailand', 14.8971921, 100.83273),
#  (194, 'London', 51.5073359, -0.12765),
#  (194, 'Ayutthaya', 14.3189468, 100.5111681),
#  (194, 'Plant', 46.2028017, 13.7822094),
#  (194, 'England', 52.5310214, -1.2649062),
#  (196, 'US', 39.7837304, -100.445882),
#  (196, 'Jackson', 32.3086744, -90.1983063),
#  (197, 'US', 39.7837304, -100.445882),
#  (198, 'Vietnam', 15.9266657, 107.9650855),
#  (198, 'Indonesia', -2.4833826, 117.8902853),
#  (198, 'the ivory tower', 22.4833927, 88.3466101),
#  (199, 'CENTEL', -16.072583, -47.9816269),
#  (199, 'Thailand Focus', 12.9283149, 100.8780481),
#  (199, 'LH', 34.1642029, 77.5848133),
#  (200, 'Thailand', 14.8971921, 100.83273),
#  (200, 'US', 39.7837304, -100.445882),
#  (200, 'Jackson Hole', 34.641109, -98.67619161204742),
#  (201, 'Thailand', 14.8971921, 100.83273),
#  (201, 'US', 39.7837304, -100.445882),
#  (202, 'Saudi Arabia', 25.6242618, 42.3528328),
#  (202, 'US', 39.7837304, -100.445882),
#  (202, 'Iran', 32.6475314, 54.5643516),
#  (202, 'U.S.', 48.6840558, 9.009657397144329),
#  (202, 'the West However', 51.0542952, -1.3381888),
#  (204, 'Chonburi Province', 13.1857117, 101.1210777),
#  (204, 'US', 39.7837304, -100.445882),
#  (204, 'Dubai', 25.074282349999997, 55.18853865430702),
#  (204, 'Russia', 64.6863136, 97.7453061),
#  (204, 'Ukraine', 49.4871968, 31.2718321),
#  (204, 'EV', 38.3881754, 27.05477765852585),
#  (204, 'Foxconn', 47.7427111, 18.08178848292425),
#  (205, 'Q4', -30.33978395, -54.31603882349927),
#  (207, 'Diane', -6.1529267, 144.8742188),
#  (209, 'Thailand', 14.8971921, 100.83273),
#  (209, 'Bangkok', 13.7524938, 100.4935089),
#  (209, 'Thais', 46.7582303, 0.9108546),
#  (210, 'US', 39.7837304, -100.445882),
#  (211, 'US', 39.7837304, -100.445882),
#  (212, 'Q2/2022', 17.665756, 102.7910096),
#  (212, 'Algeria', 28.0000272, 2.9999825),
#  (212, 'Erawan', 17.3693597, 101.8920754),
#  (212, 'Iran', 32.6475314, 54.5643516),
#  (212, 'Indonesia', -2.4833826, 117.8902853),
#  (212, 'Russia', 64.6863136, 97.7453061),
#  (212, 'Ukraine', 49.4871968, 31.2718321),
#  (213, 'US', 39.7837304, -100.445882),
#  (213, 'Goldilock', 14.5484923, 121.0640024),
#  (213, 'Taiwan', 23.9739374, 120.9820179),
#  (213, 'LH', 34.1642029, 77.5848133)]
